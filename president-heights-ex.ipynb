# %%
#Example: What is the Average Height of US Presidents?
#Using pandas to read file and extract information
import pandas as pd #import library
#read file. Remember to copy and paste the correct file directory!
dataframe = pd.read_csv('../input/us-president-height-dataset/president_heights.csv')
#check heads and few rows and columns
# !head -4 '../input/us-president-height-dataset/president_heights.csv'

# %%
# creating an array for the heights data
heights = np.array(dataframe['height(cm)'])
print(heights)

# %%
#computing summary statistics
print("mean height:       ", heights.mean())
print("standard deviation:", heights.std())
print("max height:        ", heights.max())
print("min height:        ", heights.min())

# %%
#some quantiles
print("25th percentile:", np.percentile(heights, 25))
print("75th percentile:", np.percentile(heights, 75))
print("Median:         ", np.median(heights))

# %%
#Visual representation with matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set() #set plot style

# %%
plt.hist(heights)
plt.title('Height Dist of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number')
